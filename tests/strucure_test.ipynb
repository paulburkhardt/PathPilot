# %%
import sys
import os
sys.path.append(os.path.abspath(os.pardir))
 
from src import utils
from src.data_extraction import mast3r_processor
from src import  data_extraction
from src.data_retrieval import text_to_speech
from src.data_base import DataBase

# %%
TextToSpeech = text_to_speech.TextToSpeech(None)
TextToSpeech.text_to_speech("Hello, world")
